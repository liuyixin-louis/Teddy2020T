# %%
# !pip install kashgari
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x7f3892f11a90>: Failed to establish a new connection: [Errno -3] 域名解析暂时失败')': /simple/kashgari/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x7f3892f06850>: Failed to establish a new connection: [Errno -3] 域名解析暂时失败')': /simple/kashgari/
# Collecting kashgari
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d4/da/cc2e6d092125c805d0721227f34e288657f6bbb6cd750c491227137053ba/kashgari-1.1.5-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 143 kB/s eta 0:00:011
# Collecting keras-gpt-2>=0.8.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/df/19/d11eac066ffcb61ec9edd23c02e4651eaa31f1f67c167a636dd90b6142a4/keras-gpt-2-0.14.0.tar.gz (7.7 kB)
# Collecting seqeval==0.0.10
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/55/dd/3bf1c646c310daabae47fceb84ea9ab66df7f518a31a89955290d82b8100/seqeval-0.0.10-py3-none-any.whl (7.5 kB)
# Collecting numpy==1.16.4
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/fc/d1/45be1144b03b6b1e24f9a924f23f66b4ad030d834ad31fb9e5581bd328af/numpy-1.16.4-cp37-cp37m-manylinux1_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 133 kB/s eta 0:00:01     |█████████████████████████▊      | 13.9 MB 254 kB/s eta 0:00:14
# Collecting bert4keras==0.6.5
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e3/4c/0dfe26eeeb13b46dc1a74f57c7f9531cc0881c5a8efc9f31a058f0c70f61/bert4keras-0.6.5.tar.gz (35 kB)
# Collecting gensim>=3.5.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/7d/d9/e69c5c556f16b9ac04ecd3523b39c64fbd15524bfb40cd923497bd16b6a0/gensim-3.8.2-cp37-cp37m-manylinux1_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 70 kB/s  eta 0:00:01
# Requirement already satisfied: h5py in /home/louis/anaconda3/lib/python3.7/site-packages (from kashgari) (2.10.0)
# Requirement already satisfied: scikit-learn>=0.21.1 in /home/louis/anaconda3/lib/python3.7/site-packages (from kashgari) (0.22.1)
# Requirement already satisfied: pandas>=0.23.0 in /home/louis/anaconda3/lib/python3.7/site-packages (from kashgari) (1.0.1)
# Collecting keras-bert>=0.50.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/2c/0f/cdc886c1018943ea62d3209bc964413d5aa9d0eb7e493abd8545be679294/keras-bert-0.81.0.tar.gz (29 kB)
# Requirement already satisfied: Keras in /home/louis/anaconda3/lib/python3.7/site-packages (from keras-gpt-2>=0.8.0->kashgari) (2.3.1)
# Collecting regex
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/0f/fa/a9e3ad47c189969e3233031187b323fe20005fee4bfc8edcb24f8ffbe540/regex-2020.4.4-cp37-cp37m-manylinux2010_x86_64.whl (679 kB)
#      |████████████████████████████████| 679 kB 2.5 MB/s eta 0:00:01
# Collecting keras-transformer>=0.30.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/22/b9/9040ec948ef895e71df6bee505a1f7e1c99ffedb409cb6eb329f04ece6e0/keras-transformer-0.33.0.tar.gz (11 kB)
# Requirement already satisfied: smart-open>=1.8.1 in /home/louis/anaconda3/lib/python3.7/site-packages (from gensim>=3.5.0->kashgari) (2.0.0)
# Requirement already satisfied: six>=1.5.0 in /home/louis/anaconda3/lib/python3.7/site-packages (from gensim>=3.5.0->kashgari) (1.12.0)
# Requirement already satisfied: scipy>=1.0.0 in /home/louis/anaconda3/lib/python3.7/site-packages (from gensim>=3.5.0->kashgari) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /home/louis/anaconda3/lib/python3.7/site-packages (from scikit-learn>=0.21.1->kashgari) (0.14.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/louis/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->kashgari) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/louis/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->kashgari) (2019.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/louis/anaconda3/lib/python3.7/site-packages (from Keras->keras-gpt-2>=0.8.0->kashgari) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /home/louis/anaconda3/lib/python3.7/site-packages (from Keras->keras-gpt-2>=0.8.0->kashgari) (1.0.8)
# Requirement already satisfied: pyyaml in /home/louis/anaconda3/lib/python3.7/site-packages (from Keras->keras-gpt-2>=0.8.0->kashgari) (5.3)
# Collecting keras-pos-embd>=0.10.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/09/70/b63ed8fc660da2bb6ae29b9895401c628da5740c048c190b5d7107cadd02/keras-pos-embd-0.11.0.tar.gz (5.9 kB)
# Collecting keras-multi-head>=0.22.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/40/3e/d0a64bb2ac5217928effe4507c26bbd19b86145d16a1948bc2d4f4c6338a/keras-multi-head-0.22.0.tar.gz (12 kB)
# Collecting keras-layer-normalization>=0.12.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a4/0e/d1078df0494bac9ce1a67954e5380b6e7569668f0f3b50a9531c62c1fc4a/keras-layer-normalization-0.14.0.tar.gz (4.3 kB)
# Collecting keras-position-wise-feed-forward>=0.5.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e3/59/f0faa1037c033059e7e9e7758e6c23b4d1c0772cd48de14c4b6fd4033ad5/keras-position-wise-feed-forward-0.6.0.tar.gz (4.4 kB)
# Collecting keras-embed-sim>=0.7.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/bc/20/735fd53f6896e2af63af47e212601c1b8a7a80d00b6126c388c9d1233892/keras-embed-sim-0.7.0.tar.gz (4.1 kB)
# Requirement already satisfied: boto in /home/louis/anaconda3/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim>=3.5.0->kashgari) (2.49.0)
# Requirement already satisfied: requests in /home/louis/anaconda3/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim>=3.5.0->kashgari) (2.20.0)
# Requirement already satisfied: boto3 in /home/louis/anaconda3/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim>=3.5.0->kashgari) (1.12.48)
# Collecting keras-self-attention==0.41.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1b/1c/01599219bef7266fa43b3316e4f55bcb487734d3bafdc60ffd564f3cfe29/keras-self-attention-0.41.0.tar.gz (9.3 kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/louis/anaconda3/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim>=3.5.0->kashgari) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/louis/anaconda3/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim>=3.5.0->kashgari) (2019.3.9)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/louis/anaconda3/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim>=3.5.0->kashgari) (2.5)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/louis/anaconda3/lib/python3.7/site-packages (from requests->smart-open>=1.8.1->gensim>=3.5.0->kashgari) (1.24.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/louis/anaconda3/lib/python3.7/site-packages (from boto3->smart-open>=1.8.1->gensim>=3.5.0->kashgari) (0.9.5)
# Requirement already satisfied: botocore<1.16.0,>=1.15.48 in /home/louis/anaconda3/lib/python3.7/site-packages (from boto3->smart-open>=1.8.1->gensim>=3.5.0->kashgari) (1.15.48)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/louis/anaconda3/lib/python3.7/site-packages (from boto3->smart-open>=1.8.1->gensim>=3.5.0->kashgari) (0.3.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/louis/anaconda3/lib/python3.7/site-packages (from botocore<1.16.0,>=1.15.48->boto3->smart-open>=1.8.1->gensim>=3.5.0->kashgari) (0.15.2)
# Building wheels for collected packages: keras-gpt-2, bert4keras, keras-bert, keras-transformer, keras-pos-embd, keras-multi-head, keras-layer-normalization, keras-position-wise-feed-forward, keras-embed-sim, keras-self-attention
#   Building wheel for keras-gpt-2 (setup.py) ... done
#   Created wheel for keras-gpt-2: filename=keras_gpt_2-0.14.0-py3-none-any.whl size=10527 sha256=c823eb97e95351b1a9b0c92726884f00ea8b0b33106824fb6e865afda3c24750
#   Stored in directory: /home/louis/.cache/pip/wheels/18/03/6e/3e9f5fc555d1fff94a4ce48b516faf1fd567510f850651eb14
#   Building wheel for bert4keras (setup.py) ... done
#   Created wheel for bert4keras: filename=bert4keras-0.6.5-py3-none-any.whl size=34211 sha256=13497703a5df81558e196ae78c750f58fc3211f160ed0c941912f5259d73b921
#   Stored in directory: /home/louis/.cache/pip/wheels/07/b7/93/ccf4a345ed2e0859e352ba57ff625aef9c7174216f252dd0f3
#   Building wheel for keras-bert (setup.py) ... done
#   Created wheel for keras-bert: filename=keras_bert-0.81.0-py3-none-any.whl size=37912 sha256=a61e11c56a3c45a1492867015f6fdcdb299ce96969daa86de91893d0871e5355
#   Stored in directory: /home/louis/.cache/pip/wheels/62/5f/0f/db9287d7491ac6141d6a6936571ea82a52c378a4f8e56d4997
#   Building wheel for keras-transformer (setup.py) ... done
#   Created wheel for keras-transformer: filename=keras_transformer-0.33.0-py3-none-any.whl size=13259 sha256=ce6fa5fa7de2a973c838329e199502e19a0a570e57f28da61a4dc2bb28898538
#   Stored in directory: /home/louis/.cache/pip/wheels/69/35/3d/786a7cc5622a74b07d5e5c7ff318fe0fcbabf1557d5115d8c8
#   Building wheel for keras-pos-embd (setup.py) ... done
#   Created wheel for keras-pos-embd: filename=keras_pos_embd-0.11.0-py3-none-any.whl size=7553 sha256=422549a5750f80aaf093081eefa198bbdffae1e228df1fcce991db58429d5108
#   Stored in directory: /home/louis/.cache/pip/wheels/7b/83/4a/7a12c0dd9750f0be5e413c1cd25005e7c0b73233f347e603fd
#   Building wheel for keras-multi-head (setup.py) ... done
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.22.0-py3-none-any.whl size=15373 sha256=c7d7fdb72d238a8bd8fa6899a08627cde3cb6bb3786469f797c0a74c7e89a370
#   Stored in directory: /home/louis/.cache/pip/wheels/84/04/24/eb6c1becbc8bf4de8529d83e22bc47fae43064d510955ca350
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.14.0-py3-none-any.whl size=5267 sha256=b9443663bad905a09e1de9b1822f679d67c9ee11abc02b3531c3fbdd5698194e
#   Stored in directory: /home/louis/.cache/pip/wheels/0b/2d/b9/c98adfc346c194744394ef1a2ea9f3dfbc26905cf41544d2ac
#   Building wheel for keras-position-wise-feed-forward (setup.py) ... done
#   Created wheel for keras-position-wise-feed-forward: filename=keras_position_wise_feed_forward-0.6.0-py3-none-any.whl size=5623 sha256=b5c029aee3cbb4aafa78c7c7ebbb593df204be65ec24626a635f7b320c3bb267
#   Stored in directory: /home/louis/.cache/pip/wheels/6f/97/8e/35d2314838dd45704ad39b95a375cd021658f3d6fc59119670
#   Building wheel for keras-embed-sim (setup.py) ... done
#   Created wheel for keras-embed-sim: filename=keras_embed_sim-0.7.0-py3-none-any.whl size=4674 sha256=07d9200ae7de0de8e30d47808c396343b839c3d141a1c90713f791c9f02dfc77
#   Stored in directory: /home/louis/.cache/pip/wheels/87/d3/03/eae20aa7ac5566994d8d9e1a11d99d203abf1fe0379201e5ca
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.41.0-py3-none-any.whl size=17288 sha256=57f0e6faf3c34893571e46a586caba6ffbf131dd3e4d308c0a641c6ed0fe27b7
#   Stored in directory: /home/louis/.cache/pip/wheels/56/da/9f/e596eabe11c672e4c032c6a67b697eb53bd6ec691a06703751
# Successfully built keras-gpt-2 bert4keras keras-bert keras-transformer keras-pos-embd keras-multi-head keras-layer-normalization keras-position-wise-feed-forward keras-embed-sim keras-self-attention
# ERROR: tensorboard 2.1.0 has requirement requests<3,>=2.21.0, but you'll have requests 2.20.0 which is incompatible.
# Installing collected packages: numpy, regex, keras-pos-embd, keras-self-attention, keras-multi-head, keras-layer-normalization, keras-position-wise-feed-forward, keras-embed-sim, keras-transformer, keras-gpt-2, seqeval, bert4keras, gensim, keras-bert, kashgari
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.1
#     Uninstalling numpy-1.18.1:
#       Successfully uninstalled numpy-1.18.1
#   Attempting uninstall: gensim
#     Found existing installation: gensim 2.3.0
#     Uninstalling gensim-2.3.0:
#       Successfully uninstalled gensim-2.3.0
# Successfully installed bert4keras-0.6.5 gensim-3.8.2 kashgari-1.1.5 keras-bert-0.81.0 keras-embed-sim-0.7.0 keras-gpt-2-0.14.0 keras-layer-normalization-0.14.0 keras-multi-head-0.22.0 keras-pos-embd-0.11.0 keras-position-wise-feed-forward-0.6.0 keras-self-attention-0.41.0 keras-transformer-0.33.0 numpy-1.16.4 regex-2020.4.4 seqeval-0.0.10

# %%
# 加载内置数据集
## 中文数据集
from kashgari.corpus import ChineseDailyNerCorpus

train_x, train_y = ChineseDailyNerCorpus.load_data('train')
valid_x, valid_y = ChineseDailyNerCorpus.load_data('valid')
test_x, test_y = ChineseDailyNerCorpus.load_data('test')

## 英文数据集
from kashgari.corpus import CONLL2003ENCorpus

train_x, train_y = CONLL2003ENCorpus.load_data('train')
valid_x, valid_y = CONLL2003ENCorpus.load_data('valid')
test_x, test_y = CONLL2003ENCorpus.load_data('test')

# 也可以使用自己的数据集
train_x = [['Hello', 'world'], ['Hello', 'Kashgari'], ['I', 'love', 'Beijing']]
train_y = [['O', 'O'], ['O', 'B-PER'], ['O', 'B-LOC']]

# valid_x, valid_y = train_x, train_y
# test_x, test_x = train_x, train_y
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-acc673017dad> in <module>
#       1 # 加载内置数据集
#       2 ## 中文数据集
# ----> 3 from kashgari.corpus import ChineseDailyNerCorpus
#       4
#       5 train_x, train_y = ChineseDailyNerCorpus.load_data('train')
#
# ~/anaconda3/lib/python3.7/site-packages/kashgari/__init__.py in <module>
#      31
#      32 from kashgari import layers
# ---> 33 from kashgari import corpus
#      34 from kashgari import embeddings
#      35 from kashgari import macros
#
# ~/anaconda3/lib/python3.7/site-packages/kashgari/corpus.py in <module>
#       6 from kashgari import macros as k
#       7 from typing import Tuple, List
# ----> 8 from tensorflow.python.keras.utils import get_file
#       9 from kashgari import utils
#      10
#
# ImportError: cannot import name 'get_file' from 'tensorflow.python.keras.utils' (/home/louis/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/utils/__init__.py)
